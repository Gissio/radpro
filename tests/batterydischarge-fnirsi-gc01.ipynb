# %% [markdown]
# # Battery discharge (FNIRSI GC-01)
#
# Credits: martin-machacek
#
# * Interval: 10 minutes
# * Display sleep after 30 seconds
# * Display brightness level: High
# * Rad Pro version 2.0beta22

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal

# %% [markdown]
# ## Data

# %%
# Load data
x = [4.16,4.143,4.129,4.115,4.102,4.091,4.081,4.071,4.061,4.053,4.046,4.037,4.031,4.024,4.019,4.015,4.011,4.007,4.004,4.002,3.999,3.997,3.994,3.99,3.986,3.982,3.978,3.973,3.967,3.961,3.955,3.949,3.942,3.935,3.928,3.922,3.915,3.909,3.903,3.897,3.892,3.886,3.882,3.878,3.874,3.869,3.863,3.857,3.851,3.845,3.839,3.833,3.826,3.819,3.813,3.809,3.803,3.795,3.788,3.779,3.772,3.763,3.755,3.747,3.738,3.73,3.722,3.713,3.705,3.697,3.689,3.681,3.673,3.667,3.659,3.653,3.646,3.641,3.635,3.63,3.624,3.62,3.615,3.61,3.605,3.602,3.598,3.593,3.59,3.585,3.582,3.578,3.574,3.57,3.565,3.56,3.557,3.553,3.547,3.54,3.533,3.527,3.521,3.515,3.509,3.503,3.497,3.489,3.481,3.474,3.466,3.457,3.449,3.44,3.43,3.422,3.415,3.407,3.4,3.391,3.378,3.363,3.338,3.299,3.243,3.164,3.042]

# %%
i = np.arange(0, len(x)) / 6

# Plot
plt.figure()
plt.title('Battery discharge (FNIRSI GC-01)')
plt.xlabel('Time [h]')
plt.ylabel('Battery voltage [V]')
plt.plot(i, x)
plt.show()
